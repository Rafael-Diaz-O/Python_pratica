# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafael-Diaz-O/Python_pratica/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvendio a Python

# %%
print("Hola mundo" + " 5") #Solo se pueden concatenar Strings
# Out:
# Hola mundo 5

# %%
print("Hola mundo " + "como estan?")
# Out:
# Hola mundo como estan?

# %%
print(20 +15) # Hace la operación matematica
# Out:
# 35

# %%
producto_1 = "Chocolate"
producto_2 = "Helado"
producto_3 = "Celular"

print(producto_1)
print("Productos")
print("Producto 1: " + producto_1 + "Producto 2: " + producto_2 + "Producto 3: " + producto_3)
# Out:
# Chocolate
# Productos
# Producto 1: ChocolateProducto 2: HeladoProducto 3: Celular

# %%
Total_productos= producto_1 + producto_2 + producto_3
print("Total de preductos: " + Total_productos)
# Out:
# Total de preductos: ChocolateHeladoCelular

# %%
Total_productos= producto_1 + " " +  producto_2 +  " " + producto_3 #Podemos concatenar dejando los espacios entre el texto para que sea legible
print("Total de preductos: " + Total_productos)
# Out:
# Total de preductos: Chocolate Helado Celular

# %%
amigos = 5
alquiler = 900
supermercado = 500
vehiculo = 400

total = alquiler + supermercado + vehiculo

print("Gasto total inicial del  viaje es:",total) #Con la coma podemos mostrar numeros y textos a la vez

alquiler = 800

total = alquiler + supermercado + vehiculo
print("Gasto total final  es:",total)

alquiler = alquiler - 100
print(alquiler)

print("Valor del vehiculo: " , vehiculo*2) # un forma rapida de hacer pero no es recomendada

#Version reutilizable y que esta mejor

Total_vehiculo = vehiculo*2

print("Valor total del vehiculo: ",Total_vehiculo)

Total_final = alquiler + supermercado + Total_vehiculo

print("Total final: " , Total_final)

Total_por_persona = Total_final/amigos  #Se divide el presio total entre la cantidad de amigos

print("Total a pagar por amigo: " ,Total_por_persona)
# Out:
# Gasto total inicial del  viaje es: 1800
# Gasto total final  es: 1700
# 700
# Valor del vehiculo:  800
# Valor total del vehiculo:  800
# Total final:  2000
# Total a pagar por amigo:  400.0

# %%
#Cosas que no se pueden hacer iniciar una varibale ocn un numero

#ESto nos dara error
2sandwichs = 2

#tampoco se pued eusar palabras reservadas para nombrar las variables
print = "Hola"

nombre_de_producto = "alfajore" # Nomenclatura preferida en python
nombre-de-producto = "alfajore"
nombreDeProducto = "alfajore" #Camell case
# Out:
#   File "/tmp/ipykernel_2730/2964867451.py", line 4
#     2sandwichs = 2
#     ^
# SyntaxError: invalid decimal literal

# %%
nombre_de_producto = "alfajore"

#Me muestra el tipo de dato que es mi variable
print("Tipo de dato de alquiler: " , type(alquiler))
print("Tipo de dato total_por_persona" , type(Total_por_persona))
print("Tipo de dato nombre_de_producto",type(nombre_de_producto))

juan_tiene_licencia_de_conducir = True
juan_tiene_licencia_de_conducir = False

print("Juan tiene licencia de conducir " , juan_tiene_licencia_de_conducir)
print("Tipo de dato de la variable juan: " , type(juan_tiene_licencia_de_conducir))

# %%
texto = "teXTo  raro sIn formato" #texto mal escrito

print("Texto: " , texto)

#Funciones
print(texto.upper()) #Coloca todo el texto en mayuscula
print(texto.lower()) #Coloca todo el texto en minuscula
print(texto.strip) #Elimina el espacio al final del texto

print("Texto sin los espacios repetidos en el medio")
print(texto.replace("  "," ")) # lo que hace es si ve que hay dos espacios lo remplazo por un solo espacio

#El replace sirve para cambiar cualquier carater
print(texto.replace("t","r")) # Aqui cambio las t minusculas por una r


#Aplicando varias funciones a la variables texto
print(texto.lower().strip().replace("  "," "))

texto = texto.lower().strip().replace("  "," ") #En la variable texto se guardan el resultado total de haber aplicado todas las funciones a la variable texto

#Ahora al mostrar texto en pantalla se mostrara con todos los cambios guardados
print(texto)
# Out:
# Texto:  teXTo  raro sIn formato
# TEXTO  RARO SIN FORMATO
# texto  raro sin formato
# <built-in method strip of str object at 0x7f734ef9bd70>
# Texto sin los espacios repetidos en el medio
# teXTo raro sIn formato
# reXTo  raro sIn formaro
# texto raro sin formato
# texto raro sin formato

# %%
#Como ingresar informacion

input("Ingrese su nombre" )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2730/3506171632.py in <cell line: 0>()
#       1 #Como ingresar informacion
#       2
# ----> 3 input("Ingrese su nombre" )
#       4
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
#Guardar en un variable la información

nombre = input("Ingrese su nombre : ")

print("Nombre: " , nombre)

edad = input("Ingrese su edad: ")

print("Edad: ", edad)

print("Tipo de dato de la varible edad: ",type(edad))
#con el input todos los datos se guardan como tipo String

# %%
#Pasar de String a entero

edad = int(input("Ingrese su edad: "))
#con el int le decimos a la variable que va a guardar un dato entero es decir volvemos el String que resivimos del input en entero

print("Dato de edad  ", type(edad))

print("La edad es: " + str(edad))
#Esta es una forma para concatenar enteros con strings aqui se paso de entero a string

#Hacer Strings con formato , Metodo recomendado

print(f"La edad es: {edad}")
#En este formato se colocan llaves para indicar las variables y que todo se miprima como texto sin importar el tipo de dato que sea la variable

# %%
#Condicionales

nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: "))

if edad >= 18:
  print(f"{nombre} usted puede ingresar al establecimiento por que tiene {edad} años")
else:
  print(f"{nombre} usted no puede ingresar por que tiene {edad} años por lo tanto es menor de edad ")

# %%
#Verificador si la persona aprobo o no

promedio = float(input("Ingrese su promedio: "))

if promedio >= 7:
  print(f"{nombre} Aprovo con un promedio de {promedio}")
elif promedio >= 5 and promedio<= 7 : # tiene que cumplirse las dos condiciones
  print(f"{nombre} tiene que recuperar su promedio es de {promedio}")
else:
  print(f"{nombre} reprobo con un promedio de {promedio}")

# %% [markdown]
# Aula 2: Uso de la IA

# %%
import os #importo esta libreria para trabajar con variables de entorno
from google.colab import userdata # agrego una libreria
userdata.get("Alura_gemini_api") # muestra mi api key

#Estamos guardando en la variable de entorno que llame alura curso el resultado que genera el codigo frente al igual el nombre de la variable sele
#coloca en elo corchetes []
os.environ["GEMINI_API_KEY"] = userdata.get("Alura_gemini_api") #Es obligatorio llamar asi la variable para que no de errores la variable de entorno

# %%
from google import genai # importamos esto por que poemos usar funcionalidades y herramientas para interaturas con la IA

client = genai.Client() #Se esta guardado en la variable client el motodo o funcion genai.Client() , creamos un objecto o instancia

# %%
client.models.generate_content(model = "gemini-2.5-flash",contents = "Que es la IA") # con model elegimos el modelo de gemini a usar y en contend hacemos nuestras preguntas
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""La **Inteligencia Artificial (IA)** es un campo de la informática que se enfoca en crear máquinas que puedan **simular la inteligencia humana**. En otras palabras, se trata de dotar a los sistemas informáticos de la capacidad de realizar tareas que, tradicionalmente, requieren de la cognición humana.
#
# **Objetivo principal de la IA:**
# El objetivo es que las máquinas puedan:
# 1.  **Aprender** de la experiencia (datos).
# 2.  **Razonar** para resolver problemas.
# 3.  **Percibir** el entorno (visión, voz).
# 4.  **Comprender y generar lenguaje** humano.
# 5.  **Tomar decisiones** y actuar de manera autónoma.
#
# **¿Cómo funciona (de forma simplificada)?**
# ...

# %%
#Guardando la respuesta de la ia en ua variable

respuesta = client.models.generate_content(model = "gemini-2.5-flash",contents = "Que es la IA") #aqui se hace la busqueda de la ia

# %%
print(respuesta.text) # Solo memuestra lo que esta dentro de text osea la respuesta de la ia

# %%
n = 1

while n <= 10:
  print("*")
  n = n+1
print("Ya sali del While")

# %%
chat = client.chats.create(model = "gemini-2.5-flash") # Es muy sencible ocn los errores de identacion si "gemini-2.5-flash " tiene como este ejemplo un espacio de mas
#la funcion no s eejecutara bien y no encontrar el modelo pero no dara error aun que mas adelante al querer usarlo si tendremos el error

# %%
respuesta = chat.send_message("Que es la IA")

# %%
print(respuesta)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""La **Inteligencia Artificial (IA)** es un campo de la informática que se dedica a la creación de **sistemas y máquinas capaces de realizar tareas que normalmente requieren inteligencia humana**.
#
# En términos más sencillos, la IA busca que las computadoras puedan:
#
# 1.  **Aprender** de los datos y la experiencia.
# 2.  **Razonar** y resolver problemas.
# 3.  **Comprender** el lenguaje humano.
# 4.  **Percibir** el entorno (como ver imágenes o escuchar sonidos).
# 5.  **Tomar decisiones** de forma autónoma.
#
# **No busca que las máquinas tengan conciencia o emociones** (al menos no en la actualidad), sino que puedan simular ciertas capacidades cognitivas humanas para procesar información y actuar de manera "inteligente".
#
# **Ejemplos de IA en tu día a día:**
#
# *   **Asistentes de voz:** Siri, Alexa, Google Assistant.
# ...

# %%
#Le hacemos otra preguta al chat

respuesta = chat.send_message("Cuando se lanzo chatgpt")
print(respuesta )
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.
#
# Su lanzamiento fue un evento muy significativo que popularizó la inteligencia artificial conversacional y marcó el inicio de una nueva era de interés masivo en la IA."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='OL4yaurHMqmgqtsPnrvqyQ0' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=50,
#   prompt_token_count=7,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=7
#     ),
#   ],
#   thoughts_token_count=485,
#   total_token_count=542
# ) automatic_function_calling_history=[] parsed=None

# %%
#Historial de toda la conversacion con el chat
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='Cuando se lanzo chatgpt'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.
#
#  Su lanzamiento fue un evento muy significativo que popularizó la inteligencia artificial conversacional y marcó el inicio de una nueva era de interés masivo en la IA."""
#      ),
#    ],
#    role='model'
#  )]

# %%
#Creacion de chat bot basico
prompt = input("Ingrese tu pregunta: ")

while prompt != "fin":
  respuesta = chat.send_message(prompt) # hacer la pregunta que escriba el usuario por que leera la variable prompt
  print(respuesta.text)
  prompt = input("Ingrese su pregunta(Escriba fin para terminar): ")
# Out:
# Ingrese tu pregunta: fin

# %%
#Creacion de listas

nombre = ["juan" ,11,True, "Derek"]  #Todos los tipos de datos que se pueden almacenar en la lista

nombres = ["Juan","Luara","Fernando","Jose Fina","Pedro"]
#pos         0      1       2          3            4
print(nombres)
# Out:
# ['Juan', 'Luara', 'Fernando', 'Jose Fina', 'Pedro']

# %%
print("El quinto elemento es ",nombres[4] ) #Saber el valor de un dato en espesifico
# Out:
# El quinto elemento es  Pedro

# %%
promedios = [8.5,6.5,7.3,9.5]
print(promedios[3])
# Out:
# 9.5

# %%
#Reto : sumar 1 a cada promedio pero si al sumarle e 1 este promedio no puede ser mayor que 10

cont = 0

while cont < len(promedios): #la funcion len indica la cantidad de elementos de mi lista
  promedios[cont] = promedios[cont] + 1
  if promedios[cont] > 10: #Identifica si el valor es mayor a 10 entonces coloquelo como 10 en esa posicion de mi lista
    promedios[cont] = 10
    cont = cont +1
  else:
    cont = cont +1

print(promedios)
# Out:
# [9.5, 7.5, 8.3, 10]

# %%
#SEgunda opción
n = 0

while n < 4:
  promedios[n] = promedios[n] +1
  n = n+1
  print("Los promedios mejorados son: ",promedios)
# Out:
# Los promedios mejorados son:  [9.5, 6.5, 7.3, 9.5]
# Los promedios mejorados son:  [9.5, 7.5, 7.3, 9.5]
# Los promedios mejorados son:  [9.5, 7.5, 8.3, 9.5]
# Los promedios mejorados son:  [9.5, 7.5, 8.3, 10.5]

# %%
len(promedios) # Indica la cantidad de elementos de la lista
# Out:
# 4

# %%
#Aceder a un dato de la lista pero al reves
print(promedios)
promedios[-1]
# Out:
# [9.5, 7.5, 8.3, 10.5]
# 10.5

# %%
nombres = ["Maria Silva", "Fernanda Castro","Juan Perez","Rodrigo Feliz","Juan Lala"]
print(nombres)

nombres[0:2] #me muestra un rango o una parte de la lista en este caso dedes la posicion cero hasta la dos
nombres[:3] # puedo dejar el inicio bacio y llegara hasta el tres
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juan Lala']
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez']

# %%
nombres.append("Rogelio Rodriguez") #Metodo para agregar informacion a la lista
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juan Lala', 'Rogelio Rodriguez']

# %%
print("Cantidad de elementos: ", len(nombres))
# Out:
# Cantidad de elementos:  6

# %%
nombres.extend(["Mateo Perez","Laura Fernan"]) # Me agrega los dos elementos al final de mi lista
print(nombres )
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juan Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan']

# %%
nombres.append(["Juan Oroz","Pedro Pereyra"]) # Se agrega la lista no los elementos la diferencia es por los [] que indican que es una lista
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juan Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan', ['Juan Oroz', 'Pedro Pereyra']]

# %%
nombres[8] # me muesta la lista que esta ocupando una sola posicion, la posicion 8
print(nombres[8])
nombres[8][1] # Con esto estoy acediendo a las posiciones de la lista que estan dentro de mi lista.
#DE la posicon 8 lista uno muestrame la informacion de la posicion 1 de la lista dos eso es lo que se esta haciendo aceder a los datos de una lista que esta dentro de otra
# Out:
# ['Juan Oroz', 'Pedro Pereyra']
# 'Pedro Pereyra'

# %%
#Tambien se puede hacer leyendo la lista al reves

nombres[-1][-1]
# Out:
# 'Pedro Pereyra'

# %%
nombres.remove("Maria Silva") # Elimino un valor de mi lista por valor pongo el valor que quiro borrar

# %%
nombres.pop() #Elimina el ultimo valor de tu lista
nombres #En este caso borro la lista que abiamos agregado antes dentro de nuestra lista por que era el ultimo valor
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Rodrigo Feliz',
#  'Juan Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez']

# %%
nombres.pop(2) #con esto eliminamos por posicion espesifica
nombres #Se borro el dato d ela posicion 2 que habia antes de hacer el pop
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Juan Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez']

# %% [markdown]
# Diccionarios:
#
# Estudiantes = ["clave" : valor ]

# %%
#Uso de diccionarios
nombres = ["Maria Silva", "Fernanda Castro","Juan Perez","Rodrigo Feliz","Juan Lala"]
promedios = [8.5,6.5,7.3,9.5]

#Creamos el diccionarios estudiantes
estudiantes = {
    "Maria Silva":8.5,
    "Fernando Castro":6.5,
    "Juan Perez":7.3,
    "Rodrigo Feliz":9.5
}

print(nombres)
print(promedios)
print(estudiantes)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juan Lala']
# [8.5, 6.5, 7.3, 9.5]
# {'Maria Silva': 8.5, 'Fernando Castro': 6.5, 'Juan Perez': 7.3, 'Rodrigo Feliz': 9.5}

# %%
print(estudiantes["Maria Silva"]) # busco en el diccionario que significa maria silva en este caso que ella saco un 8.5 de nota
print(estudiantes.get("Maria Silva")) # Otra forma de hacerlo
# Out:
# 8.5
# 8.5

# %%
print(estudiantes.items())
# Out:
# dict_items([('Maria Silva', 8.5), ('Fernando Castro', 6.5), ('Juan Perez', 7.3), ('Rodrigo Feliz', 9.5)])

# %%
estudiantes.pop("Maria Silva") # va a eliminar el elemento y estamos haciendo referencia por su clave maria silva lo que con lleva que con son un grupo
#Se eliminara tanto su calve como el valor asociado

print(estudiantes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1605/1196123014.py in <cell line: 0>()
# ----> 1 estudiantes.pop("Maria Silva") # va a eliminar el elemento y estamos haciendo referencia por su clave maria silva lo que con lleva que con son un grupo
#       2 #Se eliminara tanto su calve como el valor asociado
#       3
#       4 print(estudiantes)
#
# KeyError: 'Maria Silva'

# %%
estudiantes.keys() # Me muestra todas las claves de mi diccionario
# Out:
# dict_keys(['Fernando Castro', 'Juan Perez', 'Rodrigo Feliz'])

# %%
estudiantes.values() #Me muestra todos los valores
# Out:
# dict_values([6.5, 7.3, 9.5])

# %%
persona = {
    "nombre":"Juan Perez",
    "edad":25,
    "materias": ["Matematica","Literatura","Dibujo"]
}

print(persona)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25, 'materias': ['Matematica', 'Literatura', 'Dibujo']}

# %%
estudiante1 = {
    "nombre":"Juan Perez","edad":25
}

estudiante2 = {
    "nombre":"Laura Fernandez","edad":28
}

print(estudiante1)
estudiante2
# Out:
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
#Guardo los diccionarios en las listas
lista_de_estuiantes = [
     {
    "nombre":"Juan Perez","edad":25}

, {
    "nombre":"Laura Fernandez","edad":28
}]

print(lista_de_estuiantes)
print(lista_de_estuiantes[1]) #Me muestra el diccionario que se guardo en la posicion 1 de mi lista
# Out:
# [{'nombre': 'Juan Perez', 'edad': 25}, {'nombre': 'Laura Fernandez', 'edad': 28}]
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
#Para buscar no solo la posicion del diccionario si no que tambien un dato de mi diccionario
lista_de_estuiantes[1]["edad"] # se busca por valor
# Out:
# 28

# %% [markdown]
# Ciclo For

# %%
lista_de_estudiantes = [
     {
    "nombre":"Juan Perez","edad":25}

, {
    "nombre":"Laura Fernandez","edad":28
}]

n = 0

while n < len(lista_de_estudiantes):
  print(lista_de_estuiantes[n])
  n +=1

for elemento in lista_de_estudiantes: #para cada elemto una lista de estudiantes recorrera la lista de estudiantes
  print(elemento)

for n in range(5): #Para cada numero en un rango de 5
  print(n)
#El espacio donde esta la n en el for es donde esa variable se auto incrementara de forma automatica

print("Con rango definido")
for n in range(2,8): #Muestra numeros desde el 2 hasta el 7
  print(n)

#Nota: Cuendo se usa una funcion y sele pasa info como en el caso de range a eso sele llama argumento
# Pero si la estamos creando de cero y queremos poner que recivira a eso le decimos parametro

print("Con intervalos de 2 en 2")
for n in range(2,8,2): #Muestra numeros desde el 2 hasta el 7 de 2 en 2
  print(n)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}
# 0
# 1
# 2
# 3
# 4
# Con rango definido
# 2
# 3
# 4
# 5
# 6
# 7
# Con intervalos de 2 en 2
# 2
# 4
# 6

# %%
persona = {
    "nombre":"Juan Perez",
    "edad":25,
    "materias": ["Matematica","Literatura","Dibujo"]
}

for clave,valor in persona.items(): # Muestra cada calve y su valor asociado
  print(f"La clave es {clave} y el valor es {valor}")

#Solo me mostrara los numeros pares desde 0-10
for n in range(11):
  if n % 2 == 0:
    print(n)
# Out:
# La clave es nombre y el valor es Juan Perez
# La clave es edad y el valor es 25
# La clave es materias y el valor es ['Matematica', 'Literatura', 'Dibujo']
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#Funciones: Nos permiten realizar acciones sin tener que haverlas programado nosotros
#Las funciones se usan cuando nos damos cuenta que estamos copiando mucho algo o hacemos algo de forma repetida
#Otra opción es para ordenar codigo en proyectos grandes

# %%
persona_1 = " jUaN perez  "
persona_2 = "MaRIA rODRIGueZ  "
persona_3 = "  cARLos   gARcIA"
persona_4 = "ANa  lOpEZ "

# %%
def corregir_texto(texto):
  texto_nuevo = texto.lower().strip().replace("  "," ")
  print(texto_nuevo)

# %%
corregir_texto("LaUra  Fernandez")
# Out:
# laura fernandez

# %%
corregir_texto(persona_1)
corregir_texto(persona_2)
corregir_texto(persona_3)
corregir_texto(persona_4)
# Out:
# juan perez
# maria rodriguez
# carlos  garcia
# ana lopez

# %%
persona_1.split() #Me separa el nombre en elementos de una lista
#Esto es util por que nos quitamos los espacios de las palabras
# Out:
# ['jUaN', 'perez']

# %%
texto_corregido = " ".join(persona_1.split())# Lo que hago es unir con el join lo que paso como argumento y el espacio que le estoy indicando " "
#Lo que hace es unir con ese espacio todos los elementos de persona_1
print(texto_corregido)
# Out:
# jUaN perez

# %%
#Funcion mejorada
def corregir_texto(texto):
  texto_nuevo = texto.upper() #Lo pone en mayusculas
  print(texto_nuevo)
  lista_de_texto = texto_nuevo.split() # Lo pone en una lista ocupando cada palabra un espacio
  print(lista_de_texto)
  texto_final = " ".join(lista_de_texto)#Une los elementos de la lista y los separa con espacios
  print(texto_final)
  print("----------------")

# %%
corregir_texto(persona_1)
corregir_texto(persona_2)
corregir_texto(persona_3)
corregir_texto(persona_4)
# Out:
#  JUAN PEREZ
# ['JUAN', 'PEREZ']
# JUAN PEREZ
# ----------------
# MARIA RODRIGUEZ
# ['MARIA', 'RODRIGUEZ']
# MARIA RODRIGUEZ
# ----------------
#   CARLOS   GARCIA
# ['CARLOS', 'GARCIA']
# CARLOS GARCIA
# ----------------
# ANA  LOPEZ
# ['ANA', 'LOPEZ']
# ANA LOPEZ
# ----------------

# %%
#Mejorando funcion
def corregir_texto(texto):
  texto_final = " ".join(texto.upper().split())
  print(texto_final)
  print("-----------------")

# %%
corregir_texto(persona_1)
corregir_texto(persona_2)
corregir_texto(persona_3)
corregir_texto(persona_4)
# Out:
# JUAN PEREZ
# -----------------
# MARIA RODRIGUEZ
# -----------------
# CARLOS GARCIA
# -----------------
# ANA LOPEZ
# -----------------

# %%
#Vercion de una sola linea
def corregir_texto(texto):
  print(" ".join(texto.upper().split()))

# %%
corregir_texto(persona_1)
corregir_texto(persona_2)
corregir_texto(persona_3)
corregir_texto(persona_4)
# Out:
# JUAN PEREZ
# MARIA RODRIGUEZ
# CARLOS GARCIA
# ANA LOPEZ

# %%
salones = ["Salón1","Salón2","Salón3"]

# %%
import random

def ubica_alumnos(nombre_alumno,lista_salones):
  salon_asignado = random.choice(lista_salones) #Asigna de forma aleatoria a un estuainte a algun salon de la lista
  print(f"El alumno {nombre_alumno} fue asignado al salón {salon_asignado}")

  dict_alumnos = { #Creo un diccionario para guardar a los estudiantes asginados a cada salón
      "nombre":nombre_alumno,
      "Salón":salon_asignado
  }
  print(dict_alumnos)

# %%
#Hacer que las funciones devuelvan información que podamos almacenar

# %%
#Funcion mejorada
def corregir_texto(texto):
  texto_nuevo = texto.upper()
  lista_de_texto = texto_nuevo.split()
  texto_final = " ".join(lista_de_texto)
  return texto_final

# %%
nombre_optimizado = corregir_texto(persona_2) #Lo que nos debuelve la funcion lo guardamos en nuestra variable
print(nombre_optimizado)
ubica_alumnos(nombre_optimizado,salones)
#Se retorna con el fin de esa informacion que genera la funcion se pueda usaar despues en el codgio y no quede solo dentro de la funcion sin poderse usar
# Out:
# MARIA RODRIGUEZ
# El alumno MARIA RODRIGUEZ fue asignado al salón Salón3
# {'nombre': 'MARIA RODRIGUEZ', 'Salón': 'Salón3'}

# %%
ubica_alumnos("Roberto Gonzales",salones)
# Out:
# El alumno Roberto Gonzales fue asignado al salón Salón2
# {'nombre': 'Roberto Gonzales', 'Salón': 'Salón2'}

# %% [markdown]
# Desafio:
# 1. Pedirle a una IA que genere 20 emails aleatorios en strings
# 2. Crear una función que va a recibir como argumento la lista de emails y leva a pedir a una IA que los resuma en una sola linea

# %%
#Desafio mi versión:

cuerpos_emails = [
    "Hola, le informamos que hemos detectado un inicio de sesión desde un dispositivo nuevo. Por favor, revise su cuenta.",
    "Gracias por su compra. Su pedido ha sido procesado y será enviado en las próximas 24 horas.",
    "Hola a todos, los espero mañana a las 10:00 AM para discutir los objetivos del próximo trimestre.",
    "Te recordamos que tu plan mensual caduca en 3 días. Renueva ahora para no perder el acceso a los beneficios.",
    "Muchas gracias por dedicar tiempo a conocernos. Lamentablemente, en esta ocasión hemos decidido avanzar con otro candidato.",
    "Aprovecha un 30% de descuento en todos nuestros productos utilizando el código VERANO30 al finalizar la compra.",
    "Hola, te he compartido el informe financiero actualizado en Google Drive para que puedas revisarlo.",
    "Hemos actualizado nuestros términos de servicio y políticas de privacidad. Te invitamos a leer los cambios.",
    "Hemos recibido una solicitud para cambiar tu contraseña. Si no fuiste tú, por favor ignora este correo.",
    "Adjunto el reporte consolidado de las ventas realizadas durante la semana pasada. Los resultados fueron positivos.",
    "Le recordamos su cita el día viernes 20 a las 15:30. Por favor, confirme su asistencia respondiendo a este correo.",
    "¡Estamos muy contentos de tenerte aquí! Explora todas nuestras funciones y comienza a crear hoy mismo.",
    "¿Podrías confirmarme si el presupuesto final ya fue aprobado por la gerencia para seguir adelante?",
    "Todo el equipo te desea un excelente día en tu cumpleaños. ¡Disfruta mucho de este día tan especial!",
    "Lamentamos los inconvenientes presentados el día de hoy. Nuestro equipo de soporte está trabajando para solucionarlo.",
    "Únete a nuestro seminario web sobre inteligencia artificial el próximo jueves. ¡Reserva tu lugar ahora!",
    "Su perfil ha sido actualizado correctamente en nuestra base de datos. Gracias por mantener su información al día.",
    "Le informamos que el reembolso de su compra ha sido procesado. Puede tardar entre 3 a 5 días hábiles en verse reflejado.",
    "He subido los cambios al repositorio. Por favor, cuando tengas un momento, revisa el Pull Request #45.",
    "Nos encantaría conocer tu opinión. ¿Podrías dedicarnos un minuto para responder esta breve encuesta?"
]

# %%
def resumidor_emails (lista_emails):
  #1. Ponemos enmarcha la instancia cliente que esta mas arriba en el codigo con el d ehacer una consulta
  respuesta = client.models.generate_content(model = "gemini-2.5-flash",contents = f"Quiero que me resumas en una sola lina estos emails {lista_emails}")
  print(respuesta.text)

# %%
resumidor_emails(cuerpos_emails)
# Out:
# Una colección variada de notificaciones, recordatorios y solicitudes sobre actividad de cuenta, transacciones, trabajo, eventos y comunicaciones personales.

# %%
#Version 2
def resumidor_emails (lista_emails):
  #1. Ponemos enmarcha la instancia cliente que esta mas arriba en el codigo con el de hacer una consulta
  for correo in lista_emails:
    respuesta = client.models.generate_content(model = "gemini-2.5-flash",contents = f"Quiero que me resumas en una sola lina estos emails {correo}")
    print(respuesta.text)

# %%
resumidor_emails(cuerpos_emails) #La funcion si sirve solo que tiene el problema que al enviar tantas peticiones de forma seguida los servidores de gemini se sobrecargan
# Out:
# Aquí tienes una opción:
#
# **Alerta de inicio de sesión detectado en un nuevo dispositivo; revise su cuenta.**
# Tu pedido fue procesado y se enviará en 24 horas.
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# /tmp/ipykernel_12136/1417198674.py in <cell line: 0>()
# ----> 1 resumidor_emails(cuerpos_emails)
#
# /tmp/ipykernel_12136/2263633002.py in resumidor_emails(lista_emails)
#       3   #1. Ponemos enmarcha la instancia cliente que esta mas arriba en el codigo con el de hacer una consulta
#       4   for correo in lista_emails:
# ----> 5     respuesta = client.models.generate_content(model = "gemini-2.5-flash",contents = f"Quiero que me resumas en una sola lina estos emails {correo}")
#       6     print(respuesta.text)
#       7
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
# ...

# %% [markdown]
# Version del curso

# %%
def resumir_emails(cuerpo_emails):
  for numero,email in enumerate(cuerpo_emails): #Esta funcion retorna u numero por cada elemento de la lista, en la variable numero guardo los numeros de las funciones
    respuesta = client.models.generate_content( #Se coloca asi para que sea un poco mas legible y facil guiranos
        model = "gemini-2.5-flash",
        contents = f"""Te voy a enviar el cuerpo de un email y necesito que lo resumas en una sola linea.Dejame clara la intecion de dicho correo.La respuesta debe ser de una unica linea  el correo es el siguiente {email}""")
    #Se pone 3 comillas para hacegurarnos que al meter la variable y se un string y tenga comilla no lo interprete como comillla y sierre el texto asi con 3 comillas python sabe que parte es el texto que le pasamos y cual es lo que queremos que analice
    print(f"Email N° {numero + 1}:{respuesta.text}")

# %%
#Se hace con una lista corta como ejemplo y evitar la sobrecarga del modelo dado la cantidad de informacion que le estamos pasando
cuerpos_emails = [
    "Hola, le informamos que hemos detectado un inicio de sesión desde un dispositivo nuevo. Por favor, revise su cuenta.",
    "Gracias por su compra. Su pedido ha sido procesado y será enviado en las próximas 24 horas.",
    "Hola a todos, los espero mañana a las 10:00 AM para discutir los objetivos del próximo trimestre."]

# %%
resumir_emails(cuerpos_emails) # Mirar despues alcance el limite maximo de consultas de la apy de geminini version 2.5
# Out:
# Email N° 1:**Alerta de inicio de sesión desde dispositivo nuevo y solicitud para que revise su cuenta.**
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_912/1997792671.py in <cell line: 0>()
# ----> 1 resumir_emails(cuerpos_emails)
#
# /tmp/ipykernel_912/1642462473.py in resumir_emails(cuerpo_emails)
#       1 def resumir_emails(cuerpo_emails):
#       2   for numero,email in enumerate(cuerpo_emails): #Esta funcion retorna u numero por cada elemento de la lista, en la variable numero guardo los numeros de las funciones
# ----> 3     respuesta = client.models.generate_content( #Se coloca asi para que sea un poco mas legible y facil guiranos
#       4         model = "gemini-2.5-flash",
# ...

# %% [markdown]
# #Usando modelos opensours de codigo abierto usando groq

# %%
#Instalar groq para usar la api

# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 10.4 MB/s eta 0:00:00

# %%
from google.colab import userdata # importar para asegurarnos que la variable funcione
import os

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY") #Creamos la variable de entorno para que groq funcione

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
      {
        "role": "system",
        "content": "que es la ia\n"
      }
    ],
    temperature=0.5, #Que tan creativa sera la respuesta, la temperatura va de 0-2, cuanto mas baja sea la temperatura menos creativa sera la respuesta y se ira por la respuesta mas probable
    #max_completion_tokens=8192,#Esta linea de codigo me estaba generando el error
    max_tokens = 1024, #Se cambia por esta linea , lo que hace esot es fijar una cantidad de palabras que tendra la respuesta de la ia
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# **Inteligencia Artificial (IA)** es una rama de la informática que se dedica a crear sistemas y programas capaces de realizar tareas que, normalmente, requieren la inteligencia humana. Estas tareas incluyen:
#
# - **Aprendizaje**: los sistemas pueden mejorar su desempeño a partir de datos y experiencia (por ejemplo, algoritmos de *machine learning*).
# - **Razonamiento**: pueden tomar decisiones o resolver problemas basándose en reglas o patrones.
# - **Reconocimiento**: identifican y clasifican información como imágenes, voz, texto, etc.
# - **Interacción**: conversan con personas, entienden lenguaje natural y responden de forma coherente (como los chatbots).
#
# ### Tipos principales de IA
#
# | Tipo | Descripción | Ejemplos |
# |------|-------------|----------|
# | **IA estrecha (o débil)** | Diseñada para una tarea específica. | Asistentes virtuales (Siri, Alexa), sistemas de recomendación (Netflix, Spotify). |
# ...

# %%
#VErsion resumida sin bugs  un poco mas resumida
#from google.colab import userdata
#import os
from groq import Groq

# Esto carga la clave que guardaste en Secrets
#os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# Verificar que se cargó
#print("API key cargada:", bool(os.getenv("GROQ_API_KEY")))

client = Groq()  # Usa la variable de entorno

completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "user",
            "content": "que es la ia\n"
        }
    ],
    temperature=1,
    max_tokens=1024,
    top_p=1,
    stream=True
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# La Inteligencia Artificial (IA) es la capacidad de un sistema informático o un algoritmo para realizar tareas que normalmente requieren inteligencia humana, como aprender, razonar, resolver problemas, reconocer patrones y tomar decisiones. La IA busca emular las capacidades cognitivas humanas, como la comprensión del lenguaje, el razonamiento lógico y la resolución de problemas complejos.
#
# La IA puede ser clasificada en varias categorías:
#
# 1. **IA débil**: Es la capacidad de un sistema informático para realizar tareas específicas y estrechas, como reconocer patrones en una imagen o identificar la letra en una pantalla de teléfono.
# 2. **IA fuerte**: Es la capacidad de un sistema informático para emular la inteligencia humana en todo su ámbito, incluyendo la comprensión del lenguaje, el razonamiento lógico y la resolución de problemas complejos.
# ...

# %%
#Version de la appi con la correcion este llm funciona mejor en la api que el de chat gpt
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "que es la ia\n"
      }
    ],
    temperature=1,#La temperatura es el nivel de coherencia o presicion de la ia que va de 0-2 es su nivel de creatividad
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# La "IA" se refiere a "Inteligencia Artificial". La Inteligencia Artificial es un campo de la informática que se enfoca en el desarrollo de algoritmos y modelos computacionales que permiten a las máquinas simular la conducta humana inteligente, como razonar, aprender y tomar decisiones.
#
# La IA se enfoca en crear sistemas capaces de:
#
# 1. **Aprender**: Los sistemas de IA pueden aprender de la experiencia y mejorar con el tiempo.
# 2. **Razonar**: Los sistemas de IA pueden hacer inferencias y tomar decisiones lógicas basadas en datos y reglas.
# 3. **Reconocer patrones**: Los sistemas de IA pueden detectar patrones en datos y hacer predicciones basadas en ellos.
# 4. **Interactuar**: Los sistemas de IA pueden interactuar con los humanos a través de interfaces como voz, texto o pantalla de visualización, para facilitar la comunicación y la colaboración.
#
# La IA se utiliza en una variedad de aplicaciones, como:
#
# 1. **Asistentes virtuales**: Siri, Alexa, Google Assistant.
# ...

# %%
#Empezar a trabajar con la api de grog
def resumir_emails(cuerpo_emails):
  lista_resumenes = []
  for numero,email in enumerate(cuerpo_emails): #Esta funcion retorna u numero por cada elemento de la lista, en la variable numero guardo los numeros de las funciones
    respuesta = client.chat.completions.create( #Se coloca asi para que sea un poco mas legible y facil guiranos
        model = "llama-3.1-8b-instant",
        messages=[
      {
        "role": "user",
        "content": f"""Te voy a enviar el cuerpo de un email y necesito que lo resumas en una sola linea.Dejame clara la intecion de dicho correo.La respuesta debe ser de una unica linea  el correo es el siguiente {email}"""
      }
    ]
        )
    texto = respuesta.choices[0].message.content #variable encrgada de almacenar la repsuesta
    #lista_resumenes.append(texto) #Aqui almacenamos la respuesta
    #Se pone 3 comillas para hacegurarnos que al meter la variable y se un string y tenga comilla no lo interprete como comillla y sierre el texto asi con 3 comillas python sabe que parte es el texto que le pasamos y cual es lo que queremos que analice
    print(f"Email N° {numero + 1}:{texto}")
    lista_resumenes.append(f"Email N° {numero + 1}:{texto}")
  return lista_resumenes

# %%
resumir_emails(cuerpos_emails)
# Out:
# Email N° 1:"Se ha detectado actividad sospecha en su cuenta de inicio de sesión: se ruega revise y verifique si es un acceso no autorizado".
# Email N° 2:"El correo confirma la aceptación y procesamiento de un pedido con envío programado en un plazo máximo de 24 horas."
# Email N° 3:La intención del correo es informar a todos sobre una reunión programada para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.
# ['Email N° 1:"Se ha detectado actividad sospecha en su cuenta de inicio de sesión: se ruega revise y verifique si es un acceso no autorizado".',
#  'Email N° 2:"El correo confirma la aceptación y procesamiento de un pedido con envío programado en un plazo máximo de 24 horas."',
#  'Email N° 3:La intención del correo es informar a todos sobre una reunión programada para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.']

# %%
lista_resumen= resumir_emails(cuerpos_emails) #Guardamos en una variabe toda la info que nosda est funcion
# Out:
# Email N° 1:El correo indica que se ha detectado un inicio de sesión desde un dispositivo nuevo en la cuenta del destinatario y le pide que revise su cuenta.
# Email N° 2:El correo resumido en una sola linea es: "Su pedido ha sido procesado y será enviado en 24 horas".
# Email N° 3:El correo es una invitación formal a una reunión para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.

# %%
#Crear el archivo
with open("lista-de-resumenes.txt","w",encoding="utf-8")as archivo: #La primera parte es el nombre del archivo y la segunda la w es de escritura queremos que escriva la archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
  for resumen in lista_resumen:
    archivo.write(resumen + "\n")

# %%
#leer el archivo
lista_lectura= []
with open("lista-de-resumenes.txt","r",encoding="utf-8")as archivo: #La primera parte es el nombre del archivo y la segunda la r es de lectura  queremos que se lea el archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
  for linea in archivo:
    lista_lectura.append(linea)

# %%
lista_lectura #Ahora la informacion del archivo se encunetra en mi lista
# Out:
# ['Email N° 1:El correo indica que se ha detectado un inicio de sesión desde un dispositivo nuevo en la cuenta del destinatario y le pide que revise su cuenta.\n',
#  'Email N° 2:El correo resumido en una sola linea es: "Su pedido ha sido procesado y será enviado en 24 horas".\n',
#  'Email N° 3:El correo es una invitación formal a una reunión para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.\n']

# %%
#Otro metodo de lectura
with open("lista-de-resumenes.txt","r",encoding="utf-8")as archivo:
  contenido = archivo.read()

# %%
contenido #En este metodo nos da un solo bloque de texto
# Out:
# 'Email N° 1:El correo indica que se ha detectado un inicio de sesión desde un dispositivo nuevo en la cuenta del destinatario y le pide que revise su cuenta.\nEmail N° 2:El correo resumido en una sola linea es: "Su pedido ha sido procesado y será enviado en 24 horas".\nEmail N° 3:El correo es una invitación formal a una reunión para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.\n'

# %%
#Metodo respetando la estrutura orginal de nuestro archivo de texto
nueva_lista=[]
with open("lista-de-resumenes.txt","r",encoding="utf-8")as archivo:
  nueva_lista = archivo.readlines()

# %%
nueva_lista #Me guarda separado por renglones y tambien guarda el salto de linea \n
# Out:
# ['Email N° 1:El correo indica que se ha detectado un inicio de sesión desde un dispositivo nuevo en la cuenta del destinatario y le pide que revise su cuenta.\n',
#  'Email N° 2:El correo resumido en una sola linea es: "Su pedido ha sido procesado y será enviado en 24 horas".\n',
#  'Email N° 3:El correo es una invitación formal a una reunión para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.\n']

# %%
#Sin que se vean los saltos de lineas
lista_lectura= []
with open("lista-de-resumenes.txt","r",encoding="utf-8")as archivo: #La primera parte es el nombre del archivo y la segunda la r es de lectura  queremos que se lea el archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
  for linea in archivo:
    lista_lectura.append(linea.strip())

# %%
lista_lectura
# Out:
# ['Email N° 1:El correo indica que se ha detectado un inicio de sesión desde un dispositivo nuevo en la cuenta del destinatario y le pide que revise su cuenta.',
#  'Email N° 2:El correo resumido en una sola linea es: "Su pedido ha sido procesado y será enviado en 24 horas".',
#  'Email N° 3:El correo es una invitación formal a una reunión para discutir los objetivos del próximo trimestre a las 10:00 AM del día siguiente.']

# %%
import pandas as pd # lo llamamos pd por que es el estandar como todo el mundo lo conoce

# %%
df = pd.read_csv("/content/tabla.csv") #Data fream es la forma en la que se identifica una tabla en pandas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4086/3661163878.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/tabla.csv") #Data fream es la fomr en la que se identifica una tabla en pandas
#
# ...

# %%
df #Pandas grafica tabalas en una entorno de lineas de comando  para que sea mas visual
# Out:
#              Nombre  Promedio
# 0        Ana García       8.5
# 1      Carlos López       9.2
# 2   María Rodríguez       7.8
# 3        Juan Pérez       9.5
# 4    Lucía Martínez       8.9
# 5     Pedro Sánchez       6.5
# 6       Elena Gómez       9.0
# 7  Javier Fernández       8.2
# 8        Sofía Díaz       9.7
# 9      Diego Torres       7.5

# %%
df.head(4) #Grafica la cantidas de elementos que le indiquemos
# Out:
#             Nombre  Promedio
# 0       Ana García       8.5
# 1     Carlos López       9.2
# 2  María Rodríguez       7.8
# 3       Juan Pérez       9.5

# %%
df.tail(3) #Me muestra los 3 ultimos o los ultimos que indique
# Out:
#              Nombre  Promedio
# 7  Javier Fernández       8.2
# 8        Sofía Díaz       9.7
# 9      Diego Torres       7.5

# %% [markdown]
# Desafio:
#
# 1. Crear un archivo.txt apartir de una lista de preguntas provenientes de python
# 2. Leer esas pregutas desde el archivo.txt y guardarlas en una lista
# 3. Obtener respuestas de un LLM para cada una
# 4. Guardar los resultados en un nuevo archivo.csv
# 5. Leer el archivo.csv usando pandas

# %%
#Etapa 1

lista_preguntas = [
    "¿Cual es la empresa mas grande del mundo?",
    "¿Cual es la capital de Colombia?",
    "¿Cual es el rio mas largo del mundo",
    "¿Cual es el planeta mas grande del sistema solar?",
    "¿Cual es el pais mas grande del mundo?",
    "¿Cual es el animal mas grande del mundo?"

]

# %%
#Etapa 2

#2.1 Crear el archivo txt
with open("Lista-preguntas.txt","w",encoding="utf-8")as preguntas: #La primera parte es el nombre del archivo y la segunda la w es de escritura queremos que escriva la archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
  for resumen in lista_preguntas:
    preguntas.write(resumen + "\n")

# %%
#2.2 Leer el archivo

lista_lectura_preguntas= []
with open("Lista-preguntas.txt","r",encoding="utf-8")as preguntas: #La primera parte es el nombre del archivo y la segunda la r es de lectura  queremos que se lea el archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
    for linea in preguntas:
        lista_lectura_preguntas.append(linea.strip())

# %%
lista_lectura_preguntas
# Out:
# ['¿Cual es la empresa mas grande del mundo?',
#  '¿Cual es la capital de Colombia?',
#  '¿Cual es el rio mas largo del mundo',
#  '¿Cual es el planeta mas grande del sistema solar?',
#  '¿Cual es el pais mas grande del mundo?',
#  '¿Cual es el animal mas grande del mundo?']

# %%
#Etapa 3
def responder_preguntas(lista_preguntas):
  lista_respuestas = []
  for numero,pregunta in enumerate(lista_preguntas): #Esta funcion retorna u numero por cada elemento de la lista, en la variable numero guardo los numeros de las funciones
    respuesta = client.chat.completions.create( #Se coloca asi para que sea un poco mas legible y facil guiranos
        model = "llama-3.3-70b-versatile",
                                                #"llama-3.1-8b-instant",
        messages=[

      {
        "role": "user",
        "content":f"""Responde la pregunta {pregunta} en una sola linea """
      }
    ]
        )
    texto = respuesta.choices[0].message.content #variable encrgada de almacenar la repsuesta
    #lista_resumenes.append(texto) #Aqui almacenamos la respuesta
    #Se pone 3 comillas para hacegurarnos que al meter la variable y se un string y tenga comilla no lo interprete como comillla y sierre el texto asi con 3 comillas python sabe que parte es el texto que le pasamos y cual es lo que queremos que analice
    lista_respuestas.append(f"Respuesta a la pregunta N° {numero + 1}:{texto}")
  return lista_respuestas

# %%
lista_preguntas
# Out:
# ['¿Cual es la empresa mas grande del mundo?',
#  '¿Cual es la capital de Colombia?',
#  '¿Cual es el rio mas largo del mundo',
#  '¿Cual es el planeta mas grande del sistema solar?',
#  '¿Cual es el pais mas grande del mundo?',
#  '¿Cual es el animal mas grande del mundo?']

# %%
respuesta = responder_preguntas(lista_preguntas)
# Out:
# Respuesta a la pregunta N° 1:La empresa más grande del mundo suele variar según el criterio utilizado, pero en términos de capitalización de mercado y facturación, suele ser liderada por empresas como Apple, Microsoft, Amazon o Walmart.
# Respuesta a la pregunta N° 2:La capital de Colombia es Bogotá.
# Respuesta a la pregunta N° 3:El río más largo del mundo es el río Amazonas, con aproximadamente 6.400 kilómetros de longitud, aunque el río Nilo, con 6.853 kilómetros, también es considerado por muchos como el más largo.
# Respuesta a la pregunta N° 4:El planeta más grande del sistema solar es Júpiter.
# Respuesta a la pregunta N° 5:Rusia es el país más grande del mundo, cubriendo aproximadamente 17.1 millones de kilómetros cuadrados.
# Respuesta a la pregunta N° 6:La ballena azul es el animal más grande del mundo, alcanzando longitudes de hasta 33 metros y un peso de 180 toneladas.

# %%
respuesta
# Out:
# ['Respuesta a la pregunta N° 1:La empresa más grande del mundo varía según el criterio de medición, pero según el ranking de Fortune Global 500 de 2022, la empresa más grande del mundo es Walmart, con ingresos anuales de más de 572.000 millones de dólares.',
#  'Respuesta a la pregunta N° 2:La capital de Colombia es Bogotá.',
#  'Respuesta a la pregunta N° 3:El río más largo del mundo es el río Amazonas, con una longitud aproximada de 6.400 kilómetros.',
#  'Respuesta a la pregunta N° 4:El planeta más grande del sistema solar es Júpiter.',
#  'Respuesta a la pregunta N° 5:Rusia es el país más grande del mundo, con una superficie total de aproximadamente 17,1 millones de kilómetros cuadrados.',
#  'Respuesta a la pregunta N° 6:La ballena azul es el animal más grande del mundo, alcanzando longitudes de hasta 30 metros y pesando hasta 180 toneladas.']

# %%
#4 Crear el archivo csv
with open("respuesta.csv","w",encoding="utf-8")as respuestas: #La primera parte es el nombre del archivo y la segunda la w es de escritura queremos que escriva la archivo
#El apodo que le solocamos es archivo es decir nos referiremos a el como archivo , el encnding son los carateres que usa el archivo para ser creado como tildes puntos etc
  for resumen in respuesta:
    respuestas.write(resumen + "\n")

# %%
#Respuesta de la IA
import csv

with open("respuesta.csv", "w", encoding="utf-8") as archivo:
    escritor = csv.writer(archivo)
    escritor.writerow(["Número", "Respuesta"])  # encabezado
    for numero, resumen in enumerate(respuesta, start=1):
        escritor.writerow([numero, resumen])

# %%
#5

df = pd.read_csv("/content/respuesta.csv")

# %%
df
# Out:
#    Número                                          Respuesta
# 0       1  Respuesta a la pregunta N° 1:La empresa más gr...
# 1       2  Respuesta a la pregunta N° 2:La capital de Col...
# 2       3  Respuesta a la pregunta N° 3:El río más largo ...
# 3       4  Respuesta a la pregunta N° 4:El planeta más gr...
# 4       5  Respuesta a la pregunta N° 5:Rusia es el país ...
# 5       6  Respuesta a la pregunta N° 6:La ballena azul e...

# %% [markdown]
# Otra forma de hacer el desafio

# %%
#Etapa 1

lista_preguntas = [
    "¿Cual es la empresa mas grande del mundo?",
    "¿Cual es la capital de Colombia?",
    "¿Cual es el rio mas largo del mundo",
    "¿Cual es el planeta mas grande del sistema solar?",
    "¿Cual es el pais mas grande del mundo?",
    "¿Cual es el animal mas grande del mundo?"

]

# %%
with open("preguntas-mejorada.txt","w",encoding = "utf-8")as preguntas_mejorada:
  for pregunta in lista_preguntas:
    preguntas_mejorada.write(pregunta + "\n ")

# %%
#Etapa 2

lista_desafio = []
with open("preguntas-mejorada.txt","r",encoding= "utf-8") as preguntas_mejorada:
  for  linea in preguntas_mejorada:
    lista_desafio.append(linea.strip())

# %%
print(lista_desafio )
# Out:
# ['¿Cual es la empresa mas grande del mundo?', '¿Cual es la capital de Colombia?', '¿Cual es el rio mas largo del mundo', '¿Cual es el planeta mas grande del sistema solar?', '¿Cual es el pais mas grande del mundo?', '¿Cual es el animal mas grande del mundo?', '']

# %%
#Etapa 3

from groq import Groq

client = Groq()
#En esta etapa es importante tener grog inicializado para que no de erorres marcar el cuadro de texto donde este
#El client lo del os y el pip
lista_de_diccionarios_respuestas = []
for pregunta in lista_desafio:
  respuesta = client.chat.completions.create(#Esta linea de respuesta dependera del llm que utilicemos y para eso nos vamos a leer la documentacion del mismo
       model = "llama-3.3-70b-versatile",
       messages=[

            {
                "role":"user",
                "content":f"""te voy a enviar una pregunta y necesito que me devuelvas la respuesta corta.Pregunta {pregunta}"""
            }

        ]
            )

  texto =respuesta.choices[0].message.content
  lista_de_diccionarios_respuestas.append({"Preguntas":pregunta,"Respuestas":texto})

# %%
lista_de_diccionarios_respuestas
# Out:
# [{'Preguntas': '¿Cual es la empresa mas grande del mundo?',
#   'Respuestas': 'La empresa más grande del mundo varía según el criterio utilizado (ingresos, activos, número de empleados, etc.). Sin embargo, según los ingresos, algunas de las empresas más grandes del mundo son:\n\n* Walmart (minorista)\n* Amazon (tecnología y comercio electrónico)\n* Apple (tecnología)\n* Berkshire Hathaway (conglomerado)\n* Saudi Aramco (energía)\n\nPero si hablamos de la empresa más grande del mundo en términos de valor de mercado, la respuesta sería:\n\n**Apple**, con un valor de mercado superior a los 2 billones de dólares.'},
#  {'Preguntas': '¿Cual es la capital de Colombia?',
#   'Respuestas': 'La capital de Colombia es Bogotá.'},
#  {'Preguntas': '¿Cual es el rio mas largo del mundo',
# ...

# %%
#Etapa 4

with open("Pregunta-respuesta.csv","w",encoding= "utf-8") as archivo:
  archivo.write("pregunta,espuesta \n")
  for diccionario in lista_de_diccionarios_respuestas:
    archivo.write(f"{diccionario["Preguntas"]},{diccionario["Respuestas"]}\n") #ESto lo hacemos por que estamos trabajando con un lista de diccionarios
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2903/2514577140.py in <cell line: 0>()
#       3 with open("Pregunta-respuesta.csv","w",encoding= "utf-8") as archivo:
#       4   archivo.write("pregunta,espuesta \n")
# ----> 5   for diccionario in lista_de_diccionarios_respuestas:
#       6     archivo.write(f"{diccionario["Preguntas"]},{diccionario["Respuestas"]}\n") #ESto lo hacemos por que estamos trabajando con un lista de diccionarios
#       7
#
# NameError: name 'lista_de_diccionarios_respuestas' is not defined

# %%
#Etapa 5

#Para usar esto primeor se importa lalibreria de pandas y sele pone el alias de pd
df = pd.DataFrame(lista_de_diccionarios_respuestas)

# %%
df.to_csv("preguntas-respuestas.csv",index= False )

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2903/1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

# Define posibles valores para asegurar la variedad y unicidad
nombres_productos_posibles = [f"Artículo {i}" for i in range(1, 21)] # Más nombres que ítems para asegurar unicidad
categorias_posibles = ["Electrónica", "Hogar", "Alimentos", "Vestuario", "Libros", "Deportes", "Automotriz", "Jardín"]

# Generar 10 ítems aleatorios y únicos
data_inventario = {
    'Nombre de Producto': np.random.choice(nombres_productos_posibles, 10, replace=False), # Seleccionar 10 nombres únicos
    'Categoria': np.random.choice(categorias_posibles, 10, replace=True), # Las categorías pueden repetirse
    'Precio': np.round(np.random.uniform(10.0, 500.0, 10), 2), # Precios entre 10 y 500 con dos decimales
    'Stock': np.random.randint(0, 200, 10) # Stock entre 0 y 199
}

df_inventario = pd.DataFrame(data_inventario)

# %%
# Mostrar el DataFrame creado
display(df_inventario.head(10))
# Out:
#   Nombre de Producto   Categoria  Precio  Stock
# 0         Artículo 8   Alimentos  193.63    130
# 1         Artículo 1   Alimentos  334.16    108
# 2        Artículo 18  Automotriz  184.10    193
# 3         Artículo 7    Deportes  113.95    139
# 4        Artículo 17    Deportes  278.90     53
# 5        Artículo 20      Jardín  489.45    132
# 6         Artículo 3   Vestuario  408.92    189
# 7        Artículo 14   Alimentos  281.68     92
# 8        Artículo 13   Vestuario  426.03     37
# 9         Artículo 9      Libros  340.72    162

# %%
df_inventario["Categoria"]
# Out:
# 0    Automotriz
# 1    Automotriz
# 2        Jardín
# 3      Deportes
# 4      Deportes
# 5    Automotriz
# 6    Automotriz
# 7     Alimentos
# 8     Alimentos
# 9         Hogar
# Name: Categoria, dtype: object

# %%
df_inventario["Categoria"].unique() #Me muestra la informacion de la columan en un array, se hace un array
# Out:
# array(['Automotriz', 'Jardín', 'Deportes', 'Alimentos', 'Hogar'],
#       dtype=object)

# %%
set(df_inventario["Categoria"]) #De la columna sacamos los datos y creamos un diccionario
# Out:
# {'Alimentos', 'Automotriz', 'Deportes', 'Hogar', 'Jardín'}

# %%
#Aplicar u filtro donde solo me muestre los productos de la categoria hogar
df_inventario[df_inventario["Categoria"] == "Hogar"] #Lo que hago es primero identificar la columna categoria y decirle que solo me muestre las que sean igual a la palabra hogar
# Out:
#   Nombre de Producto Categoria  Precio  Stock
# 4        Artículo 20     Hogar  468.87    122
# 6        Artículo 10     Hogar  400.27    194

# %%
#Filtrar por numero si es mayor

df_inventario[df_inventario["Stock"] > 70]
# Out:
#   Nombre de Producto  Categoria  Precio  Stock
# 1         Artículo 8  Vestuario  324.49     73
# 2         Artículo 6     Libros   41.50     85
# 3        Artículo 18  Vestuario  435.82    116
# 4        Artículo 20      Hogar  468.87    122
# 6        Artículo 10      Hogar  400.27    194
# 7        Artículo 19  Vestuario  203.15    117

# %%
#Ver el shape(Forma) de un Dataframe, muestra la cantidad de filas y columnas

df_inventario.shape
# Out:
# (10, 4)

# %%
#Crear un variable donde poder almacenar el resultado del filtro

stock_mayor_70 = df_inventario[df_inventario["Stock"]>70]

stock_mayor_70
# Out:
#   Nombre de Producto  Categoria  Precio  Stock
# 1         Artículo 8  Vestuario  324.49     73
# 2         Artículo 6     Libros   41.50     85
# 3        Artículo 18  Vestuario  435.82    116
# 4        Artículo 20      Hogar  468.87    122
# 6        Artículo 10      Hogar  400.27    194
# 7        Artículo 19  Vestuario  203.15    117

# %%
stock_mayor_70.shape
# Out:
# (6, 4)

# %%
df_inventario[(df_inventario["Categoria"] == "Vestuario") & (df_inventario["Stock"] > 100 )]
# cuando usamos un amperstan & las condiciones deben ir entre parentecis ()
# Out:
#   Nombre de Producto  Categoria  Precio  Stock
# 3        Artículo 18  Vestuario  435.82    116
# 7        Artículo 19  Vestuario  203.15    117

# %% [markdown]
# # ILOC Y LOC

# %%
df_inventario.iloc[2] #Me srve para buscar por indice
# Out:
# Nombre de Producto    Artículo 6
# Categoria                 Libros
# Precio                      41.5
# Stock                         85
# Name: 2, dtype: object

# %%
df_inventario.iloc[2:4] #Estamos buscando por rango
# Out:
#   Nombre de Producto  Categoria  Precio  Stock
# 2         Artículo 6     Libros   41.50     85
# 3        Artículo 18  Vestuario  435.82    116

# %%
df_inventario.iloc[:5] #Al dejar vacio entonces python lo toma como que empeiza desde cero
# Out:
#   Nombre de Producto  Categoria  Precio  Stock
# 0        Artículo 12  Alimentos  110.75      4
# 1         Artículo 8  Vestuario  324.49     73
# 2         Artículo 6     Libros   41.50     85
# 3        Artículo 18  Vestuario  435.82    116
# 4        Artículo 20      Hogar  468.87    122

# %%
df_inventario.iloc[-2] #Se puede hacer el inverso del indice
# Out:
# Nombre de Producto    Artículo 7
# Categoria                 Libros
# Precio                     94.04
# Stock                         50
# Name: 8, dtype: object

# %%
df_inventario[2:] #Empezamos en 2  hasta acabar
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20             Jardín  489.45    132
# Artículo 3           Vestuario  408.92    189
# Artículo 14          Alimentos  281.68     92
# Artículo 13          Vestuario  426.03     37
# Artículo 9              Libros  340.72    162

# %%
df_inventario = df_inventario.set_index("Nombre de Producto") #Estoy reemplazando el índice numérico por la columna 'Nombre de Producto', que ahora pasa a ser el nuevo índice del DataFrame

# %%
display(df_inventario) #Me muestra la tabla
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 8           Alimentos  193.63    130
# Artículo 1           Alimentos  334.16    108
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20             Jardín  489.45    132
# Artículo 3           Vestuario  408.92    189
# Artículo 14          Alimentos  281.68     92
# Artículo 13          Vestuario  426.03     37
# Artículo 9              Libros  340.72    162

# %%
#La diferencia entre iloc y loc es que iloc sirve para indice numerico y loc sirve con indice de texto

# %%
df_inventario.loc["Artículo 7"] #Tener en cuenta que si no esta exatamente igual como aparese en la tabla no funcionara esto debe de incluir la misma cantidad de espacios
# Out:
# Categoria    Deportes
# Precio         113.95
# Stock             139
# Name: Artículo 7, dtype: object

# %%
df_inventario[:"Artículo 14"]
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 8           Alimentos  193.63    130
# Artículo 1           Alimentos  334.16    108
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20             Jardín  489.45    132
# Artículo 3           Vestuario  408.92    189
# Artículo 14          Alimentos  281.68     92

# %%
df_inventario["Artículo 7":]
# Out:
#                     Categoria  Precio  Stock
# Nombre de Producto
# Artículo 7           Deportes  113.95    139
# Artículo 17          Deportes  278.90     53
# Artículo 20            Jardín  489.45    132
# Artículo 3          Vestuario  408.92    189
# Artículo 14         Alimentos  281.68     92
# Artículo 13         Vestuario  426.03     37
# Artículo 9             Libros  340.72    162

# %%
df_inventario["Artículo 18":"Artículo 20"]
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20             Jardín  489.45    132

# %%
df_inventario.loc[["Artículo 18","Artículo 20"],["Categoria","Stock"]] #Mira la info de dos articulos en este caso miro la categoria y el stock
# Out:
#                      Categoria  Stock
# Nombre de Producto
# Artículo 18         Automotriz    193
# Artículo 20             Jardín    132

# %%
jardin = df_inventario[df_inventario["Categoria"] == "Jardín"]

# %%
jardin
# Out:
#                    Categoria  Precio  Stock
# Nombre de Producto
# Artículo 20           Jardín  489.45    132

# %%
df_inventario.loc[jardin.index,["Precio","Stock"]] # lo que hacemos e buscar por indice para que nos muestre jardin estamos haciendo una condulta dentro de otra en este caso
#Como ya filtramos la categoria de solo jardin ahora hacemos otro filtro que sera que solo me muestre los precios y el stock
# Out:
#                     Precio  Stock
# Nombre de Producto
# Artículo 20         489.45    132

# %%
df_inventario
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 8           Alimentos  193.63    130
# Artículo 1           Alimentos  334.16    108
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20             Jardín  489.45    132
# Artículo 3           Vestuario  408.92    189
# Artículo 14          Alimentos  281.68     92
# Artículo 13          Vestuario  426.03     37
# Artículo 9              Libros  340.72    162

# %%
#Cambiar el nombre de una categoria
df_inventario.loc[jardin.index,"Categoria"]= "Plantas" #Cambie el nombre de la categoria jardin por el nombre de plantas

# %%
df_inventario
# Out:
#                      Categoria  Precio  Stock
# Nombre de Producto
# Artículo 8           Alimentos  193.63    130
# Artículo 1           Alimentos  334.16    108
# Artículo 18         Automotriz  184.10    193
# Artículo 7            Deportes  113.95    139
# Artículo 17           Deportes  278.90     53
# Artículo 20            Plantas  489.45    132
# Artículo 3           Vestuario  408.92    189
# Artículo 14          Alimentos  281.68     92
# Artículo 13          Vestuario  426.03     37
# Artículo 9              Libros  340.72    162

# %% [markdown]
# #Pratica de lo aprendido

# %%
#Sugerencia crear un dataframe para praticar de algo que te guste para ir mejorando e ir praticando haciendo consultas ejemplo un data frame de picachu

# %%
import pandas as pd
import numpy as np

# Definir algunos nombres de Pokémon y tipos para el ejemplo
pokemon_names = [
    "Pikachu", "Charmander", "Bulbasaur", "Squirtle", "Jigglypuff",
    "Meowth", "Psyduck", "Snorlax", "Gyarados", "Mewtwo",
    "Eevee", "Gengar", "Lucario", "Greninja", "Charizard"
]

pokemon_types = [
    "Eléctrico", "Fuego", "Planta", "Agua", "Normal",
    "Psíquico", "Volador", "Dragón", "Fantasma", "Lucha", "Acero", "Siniestro", "Hada", "Tierra", "Roca"
]

# Generar datos aleatorios para 20 Pokémon
data_pokemon = {
    'Nombre': np.random.choice(pokemon_names, 20, replace=True), # Cambiado a 20 y replace=True para permitir nombres repetidos
    'Tipo 1': np.random.choice(pokemon_types, 20, replace=True),
    'Tipo 2': np.random.choice(pokemon_types + [None], 20, replace=True), # Algunos Pokémon no tienen un segundo tipo
    'HP': np.random.randint(40, 150, 20),
    'Ataque': np.random.randint(40, 150, 20),
    'Defensa': np.random.randint(40, 150, 20),
    'Velocidad': np.random.randint(30, 180, 20)
}

df_pokemon = pd.DataFrame(data_pokemon)

# %%
# Mostrar el DataFrame de Pokémon
display(df_pokemon.head(10))
# Out:
#        Nombre     Tipo 1     Tipo 2   HP  Ataque  Defensa  Velocidad
# 0       Eevee      Acero      Fuego   68      50       53        103
# 1       Eevee      Fuego       Roca  109      42      120        172
# 2  Charmander    Volador       Agua  133     103       41         79
# 3     Lucario   Psíquico     Planta  111     136      124        166
# 4     Psyduck      Fuego      Fuego  140     143      142        100
# 5     Lucario      Lucha       Hada  113     145       76         34
# 6     Lucario    Volador      Lucha  130      53       78        109
# 7     Psyduck  Eléctrico     Planta   86     124      134         87
# 8   Charizard      Fuego     Normal   68      69       67        110
# 9     Pikachu     Dragón  Eléctrico  113     126       92         93

# %% [markdown]
# #Desafio
#
# 1. Cargar un archivo csv con feedback de clientes
# 2. Usar un LLM para clasificar el sentimiento de cada feedback ( positivo,negativo y neutro)
# 3. Agregar esa clasificacion al DataFrame

# %%
print(os.listdir('/content/')) #Verifico como estan guardados los archivos en el colab
#Importante para esto tener activado la variable de entorno
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1637/38603009.py in <cell line: 0>()
# ----> 1 print(os.listdir('/content/')) #Verifico como estan guardados los archivos en el colab
#       2 #Importante para esto tener activado la variable de entorno
#
# NameError: name 'os' is not defined

# %%
#Etapa 1
import pandas as pd

df_reviews = pd.read_csv("/content/reviews - reviews.csv")

# %%
df_reviews
# Out:
#         reviewerID        asin                       reviewerName  \
# 0   A2FII3I2MBMUIA  B007WTAJTO                                1K3
# 1    A3H99DFEG68SR  B007WTAJTO                                1m2
# 2   A375ZM4U047O79  B007WTAJTO                       2&amp;1/2Men
# 3   A2IDCSC6NVONIZ  B007WTAJTO                            2Cents!
# 4   A26YHXZD5UFPVQ  B007WTAJTO                         2K1Toaster
# 5   A2Q3ICGWZLY3JJ  B007WTAJTO                              98020
# 6    AF24M1HKIZ7QC  B007WTAJTO  Abdulrahman J. Alrashed "dr34m3r"
# 7   A1KIF9Z5VFPH7H  B007WTAJTO        Abel Feliciano "Ace Master"
# 8   A1FKE13D77L3Y3  B007WTAJTO          Abraham Arturo Meza Marin
# 9   A1X1FX3NSOFCT3  B007WTAJTO  Abused Commuter "abused_commuter"
# 10  A3RV1L35IPTV61  B007WTAJTO                         abushaheed
# 11  A2RJ7DAL63MN1F  B007WTAJTO                      Ace of Sevens
# 12  A3IJIFZ5HH819V  B007WTAJTO                             A. Cho
# ...

# %%
df_reviews.head()
# Out:
#        reviewerID        asin  reviewerName  \
# 0  A2FII3I2MBMUIA  B007WTAJTO           1K3
# 1   A3H99DFEG68SR  B007WTAJTO           1m2
# 2  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men
# 3  A2IDCSC6NVONIZ  B007WTAJTO       2Cents!
# 4  A26YHXZD5UFPVQ  B007WTAJTO    2K1Toaster
#
#                                           reviewText  unixReviewTime  \
# 0  it works as expected. I should have sprung for...      1356220800
# 1  This think has worked out great.Had a diff. br...      1384992000
# 2  Bought it with Retail Packaging, arrived legit...      1373673600
# 3  It's mini storage.  It doesn't do anything els...      1367193600
# 4  I have it in my phone and it never skips a bea...      1382140800
#
#    reviewTime  day_diff  helpful_yes  total_vote
# 0  23/12/2012       715            0           0
# 1  21/11/2013       382            0           0
# 2  13/07/2013       513            0           0
# 3  29/04/2013       588            0           0
# ...

# %%
# !pip install -q groq

# %%
from google.colab import userdata

import os

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %%
#Etapa 3
def responder_preguntas(lista_preguntas):
  lista_respuestas = []
  for numero,pregunta in enumerate(lista_preguntas): #Esta funcion retorna u numero por cada elemento de la lista, en la variable numero guardo los numeros de las funciones
    respuesta = client.chat.completions.create( #Se coloca asi para que sea un poco mas legible y facil guiranos
        model = "llama-3.3-70b-versatile",
                                                #"llama-3.1-8b-instant",
        messages=[

      {
        "role": "user",
        "content":f"""Responde la pregunta {pregunta} en una sola linea """
      }
    ]
        )
    texto = respuesta.choices[0].message.content #variable encrgada de almacenar la repsuesta
    #lista_resumenes.append(texto) #Aqui almacenamos la respuesta
    #Se pone 3 comillas para hacegurarnos que al meter la variable y se un string y tenga comilla no lo interprete como comillla y sierre el texto asi con 3 comillas python sabe que parte es el texto que le pasamos y cual es lo que queremos que analice
    lista_respuestas.append(f"Respuesta a la pregunta N° {numero + 1}:{texto}")
  return lista_respuestas

# %%
reviews = df_reviews["reviewText"]

reviews
# Out:
# 0     it works as expected. I should have sprung for...
# 1     This think has worked out great.Had a diff. br...
# 2     Bought it with Retail Packaging, arrived legit...
# 3     It's mini storage.  It doesn't do anything els...
# 4     I have it in my phone and it never skips a bea...
# 5     It works, but file writes are a bit slower tha...
# 6     I bought 2 of those SanDisk 32 GB microSD , us...
# 7     The memory card is an excellent condition and ...
# 8     I bougth this micro SD card after some trubles...
# 9     Ordered this for a Galaxy S3.  Lasted a few mo...
# 10    more like 8mb/s in my Note 10.1 and that's usi...
# 11    I used this for a few months in my phone, then...
# 12    everything about it was great, except for the ...
# 13    Used in my phone it's plenty fast and works ju...
# 14    This card advertises itself as UHS1 but it's a...
# 15    I bought this SD card for my android phone thi...
# 16    good card. work as describes. haven't had any ...
# ...

# %%
#Etapa 2

from groq import Groq

client = Groq()

def clasificacion_reviews(reviews):
  lista_clasificacion = []
  for review in reviews: #Recorro la lista de reviews que sele pase como atributo
    respuesta = client.chat.completions.create(
        model = "llama-3.3-70b-versatile",

        messages = [
            {
                "role":"user",
                "content":f"""Analiza la review {review} y en base a la informacion clasificala como positivo,negativo o neutro, no medes explicacion  solo clasificalo"""
            }
        ]
    )
    texto = respuesta.choices[0].message.content #Muestra solo el texto
    lista_clasificacion.append(texto)
  return lista_clasificacion

# %%
clasificaciones = clasificacion_reviews(reviews)

# %%
print(clasificaciones)
# Out:
# ['Neutro', 'Positivo.', 'Positivo.', 'Positivo', 'Positivo.', 'Neutro', 'Negativo', 'Positivo', 'Negativo', 'Negativo', 'Neutro', 'Negativo', 'Negativo', 'Positivo', 'Negativo', 'Negativo.', 'Positivo', 'Positivo', 'Negativo', 'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Negativo', 'Negativo', 'Negativo', 'Negativo', 'Negativo', 'Neutro', 'Positivo', 'Negativo.', 'Negativo', 'Positivo', 'Neutro', 'Neutro', 'Negativo', 'Negativo', 'Neutro', 'Negativo', 'Negativo.']

# %%
#Etapa 3

df_reviews["Clasificacion"] = clasificaciones #Creo la columna y lo subo la informacion en el DataFrame

# %%
df_reviews
# Out:
#         reviewerID        asin                       reviewerName  \
# 0   A2FII3I2MBMUIA  B007WTAJTO                                1K3
# 1    A3H99DFEG68SR  B007WTAJTO                                1m2
# 2   A375ZM4U047O79  B007WTAJTO                       2&amp;1/2Men
# 3   A2IDCSC6NVONIZ  B007WTAJTO                            2Cents!
# 4   A26YHXZD5UFPVQ  B007WTAJTO                         2K1Toaster
# 5   A2Q3ICGWZLY3JJ  B007WTAJTO                              98020
# 6    AF24M1HKIZ7QC  B007WTAJTO  Abdulrahman J. Alrashed "dr34m3r"
# 7   A1KIF9Z5VFPH7H  B007WTAJTO        Abel Feliciano "Ace Master"
# 8   A1FKE13D77L3Y3  B007WTAJTO          Abraham Arturo Meza Marin
# 9   A1X1FX3NSOFCT3  B007WTAJTO  Abused Commuter "abused_commuter"
# 10  A3RV1L35IPTV61  B007WTAJTO                         abushaheed
# 11  A2RJ7DAL63MN1F  B007WTAJTO                      Ace of Sevens
# 12  A3IJIFZ5HH819V  B007WTAJTO                             A. Cho
# ...

# %% [markdown]
# #Otra forma de hacerlo

# %%
#Etapa 1

df_reviews = pd.read_csv("/content/reviews - reviews.csv")

# %%
columna_de_reviews = df_reviews["reviewText"]

# %%
columna_de_reviews
# Out:
# 0     it works as expected. I should have sprung for...
# 1     This think has worked out great.Had a diff. br...
# 2     Bought it with Retail Packaging, arrived legit...
# 3     It's mini storage.  It doesn't do anything els...
# 4     I have it in my phone and it never skips a bea...
# 5     It works, but file writes are a bit slower tha...
# 6     I bought 2 of those SanDisk 32 GB microSD , us...
# 7     The memory card is an excellent condition and ...
# 8     I bougth this micro SD card after some trubles...
# 9     Ordered this for a Galaxy S3.  Lasted a few mo...
# 10    more like 8mb/s in my Note 10.1 and that's usi...
# 11    I used this for a few months in my phone, then...
# 12    everything about it was great, except for the ...
# 13    Used in my phone it's plenty fast and works ju...
# 14    This card advertises itself as UHS1 but it's a...
# 15    I bought this SD card for my android phone thi...
# 16    good card. work as describes. haven't had any ...
# ...

# %%
#Etapa 2

client = Groq()

lista_de_analisis = []
for numero,review in enumerate(columna_de_reviews):
    respuesta = client.chat.completions.create(
        model = "llama-3.3-70b-versatile",

        messages = [
            {
                "role":"user",
                "content":f"""Debes analizar la reseña que yo te envio y retornar un analisis de sentimiento.
                Debes responder con: Positivo,Negativo o Neutro. Ejemplo:

                Me encanto el producto -> Positivo
                El producto no es nada especial -> Neutro
                No me gusto el producto -> Negativo

                Debes responder solamente una de esas tres opciones (Positiva,Neutra o Negativa).No agreges texto o explicaciones


                Reseña: {review}"""
            }
        ]
    )
    texto = respuesta.choices[0].message.content

    print(f"Review {numero}: {review} --> sentimiento {texto} ")
    lista_de_analisis.append(texto)
# Out:
# Review 0: it works as expected. I should have sprung for the higher capacity.  I think its made a bit cheesier than the earlier versions; the paint looks not as clean as before --> sentimiento Neutro
# Review 1: This think has worked out great.Had a diff. bran 64gb card and if went south after 3 months.This one has held up pretty well since I had my S3, now on my Note3.*** update 3/21/14I've had this for a few months and have had ZERO issue's since it was transferred from my S3 to my Note3 and into a note2. This card is reliable and solid!Cheers! --> sentimiento Positivo
# Review 2: Bought it with Retail Packaging, arrived legit, in a orange envelope, english version not asian like the picture shows. arrived quickly, bought a 32 and 16 both retail packaging for my htc one sv and Lg Optimus, both cards in working order, probably best price you'll get for a nice sd card --> sentimiento Positivo
# ...

# %%
lista_de_analisis
# Out:
# ['Neutro',
#  'Positivo',
#  'Positivo',
#  'Positivo',
#  'Positivo',
#  'Neutro',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Positivo',
#  'Negativo',
#  'Neutro',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Neutro',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo']

# %%
#Etapa 3

df_reviews["Sentimientos"] = lista_de_analisis #Lo que hace e Dataframe es que si asignamos info a una columna que no
#existe entonces lo que ara sera crearla

df_reviews.head()
# Out:
#        reviewerID        asin  reviewerName  \
# 0  A2FII3I2MBMUIA  B007WTAJTO           1K3
# 1   A3H99DFEG68SR  B007WTAJTO           1m2
# 2  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men
# 3  A2IDCSC6NVONIZ  B007WTAJTO       2Cents!
# 4  A26YHXZD5UFPVQ  B007WTAJTO    2K1Toaster
#
#                                           reviewText  unixReviewTime  \
# 0  it works as expected. I should have sprung for...      1356220800
# 1  This think has worked out great.Had a diff. br...      1384992000
# 2  Bought it with Retail Packaging, arrived legit...      1373673600
# 3  It's mini storage.  It doesn't do anything els...      1367193600
# 4  I have it in my phone and it never skips a bea...      1382140800
#
#    reviewTime  day_diff  helpful_yes  total_vote Sentimientos
# 0  23/12/2012       715            0           0       Neutro
# 1  21/11/2013       382            0           0     Positivo
# 2  13/07/2013       513            0           0     Positivo
# ...

# %% [markdown]
# #Gestion de errores

# %%
try:
  edad = int(input("Ingrese su edad: "))
except:#Los errores sele llama exepciones son cosas que rompen el codigo y impiden su correcto funcionamiento
  print("No ingresaste un número")#Si ubiera una error saldria el mensaje de no ingresaste un numero indicando al usuario que debe colocar un numero para que el programa funcione
# Out:
# Ingrese su edad: e
# No ingresaste un número

# %%
try:
  edad = int(input("Ingrese su edad: "))
except ValueError as ve:
  print("No ingresaste un número")
  print("El erro es, " , ve) #Muestra cual es el error
# Out:
# Ingrese su edad: e
# No ingresaste un número
# El erro es,  invalid literal for int() with base 10: 'e'

# %%
try:
  persona = 6
  persona2 = "Juan,Pedro,Laura,Maria"
  persona+persona2
except ValueError as ve: #Es error de valor eso indica el nombre de la variable que renombramos como ve
  print("no ingresaste un número")
  print("El error es, " , ve)
  #Esto me muestra que puedo tener mas de una exepcion o error previsto y lo que se puede hacer si pasa
except TypeError  as te:#Aqui tenemos en cuenta un error de tipos de datos
  print("No puedes sumar un número con un String")
  print("El error es, " , te)
  #Se puede colocar el finally para mostrar algo al final de haber ejecutado el codigo
finally:
  print("Fin del programa :D")
#En finally sirve como otra opcion donde podemos darle otra oportunidad al usuario que haga el proceso bien
#Se puede usar como segunda oportunidad
# Out:
# No puedes sumar un número con un String
# El error es,  unsupported operand type(s) for +: 'int' and 'str'
# Fin del programa :D
