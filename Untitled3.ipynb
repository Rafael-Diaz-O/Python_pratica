# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafael-Diaz-O/Python_pratica/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvendio a Python

# %%
print("Hola mundo" + " 5") #Solo se pueden concatenar Strings
# Out:
# Hola mundo 5

# %%
print("Hola mundo " + "como estan?")
# Out:
# Hola mundo como estan?

# %%
print(20 +15) # Hace la operación matematica
# Out:
# 35

# %%
producto_1 = "Chocolate"
producto_2 = "Helado"
producto_3 = "Celular"

print(producto_1)
print("Productos")
print("Producto 1: " + producto_1 + "Producto 2: " + producto_2 + "Producto 3: " + producto_3)
# Out:
# Chocolate
# Productos
# Producto 1: ChocolateProducto 2: HeladoProducto 3: Celular

# %%
Total_productos= producto_1 + producto_2 + producto_3
print("Total de preductos: " + Total_productos)
# Out:
# Total de preductos: ChocolateHeladoCelular

# %%
Total_productos= producto_1 + " " +  producto_2 +  " " + producto_3 #Podemos concatenar dejando los espacios entre el texto para que sea legible
print("Total de preductos: " + Total_productos)
# Out:
# Total de preductos: Chocolate Helado Celular

# %%
amigos = 5
alquiler = 900
supermercado = 500
vehiculo = 400

total = alquiler + supermercado + vehiculo

print("Gasto total inicial del  viaje es:",total) #Con la coma podemos mostrar numeros y textos a la vez

alquiler = 800

total = alquiler + supermercado + vehiculo
print("Gasto total final  es:",total)

alquiler = alquiler - 100
print(alquiler)

print("Valor del vehiculo: " , vehiculo*2) # un forma rapida de hacer pero no es recomendada

#Version reutilizable y que esta mejor

Total_vehiculo = vehiculo*2

print("Valor total del vehiculo: ",Total_vehiculo)

Total_final = alquiler + supermercado + Total_vehiculo

print("Total final: " , Total_final)

Total_por_persona = Total_final/amigos  #Se divide el presio total entre la cantidad de amigos

print("Total a pagar por amigo: " ,Total_por_persona)
# Out:
# Gasto total inicial del  viaje es: 1800
# Gasto total final  es: 1700
# 700
# Valor del vehiculo:  800
# Valor total del vehiculo:  800
# Total final:  2000
# Total a pagar por amigo:  400.0

# %%
#Cosas que no se pueden hacer iniciar una varibale ocn un numero

#ESto nos dara error
2sandwichs = 2

#tampoco se pued eusar palabras reservadas para nombrar las variables
print = "Hola"

nombre_de_producto = "alfajore" # Nomenclatura preferida en python
nombre-de-producto = "alfajore"
nombreDeProducto = "alfajore" #Camell case

# %%
nombre_de_producto = "alfajore"

#Me muestra el tipo de dato que es mi variable
print("Tipo de dato de alquiler: " , type(alquiler))
print("Tipo de dato total_por_persona" , type(Total_por_persona))
print("Tipo de dato nombre_de_producto",type(nombre_de_producto))

juan_tiene_licencia_de_conducir = True
juan_tiene_licencia_de_conducir = False

print("Juan tiene licencia de conducir " , juan_tiene_licencia_de_conducir)
print("Tipo de dato de la variable juan: " , type(juan_tiene_licencia_de_conducir))
# Out:
# Tipo de dato de alquiler:  <class 'int'>
# Tipo de dato total_por_persona <class 'float'>
# Tipo de dato nombre_de_producto <class 'str'>
# Juan tiene licencia de conducir  False
# Tipo de dato de la variable juan:  <class 'bool'>

# %%
texto = "teXTo  raro sIn formato" #texto mal escrito

print("Texto: " , texto)

#Funciones
print(texto.upper()) #Coloca todo el texto en mayuscula
print(texto.lower()) #Coloca todo el texto en minuscula
print(texto.strip) #Elimina el espacio al final del texto

print("Texto sin los espacios repetidos en el medio")
print(texto.replace("  "," ")) # lo que hace es si ve que hay dos espacios lo remplazo por un solo espacio

#El replace sirve para cambiar cualquier carater
print(texto.replace("t","r")) # Aqui cambio las t minusculas por una r


#Aplicando varias funciones a la variables texto
print(texto.lower().strip().replace("  "," "))

texto = texto.lower().strip().replace("  "," ") #En la variable texto se guardan el resultado total de haber aplicado todas las funciones a la variable texto

#Ahora al mostrar texto en pantalla se mostrara con todos los cambios guardados
print(texto)
# Out:
# Texto:  teXTo  raro sIn formato
# TEXTO  RARO SIN FORMATO
# texto  raro sin formato
# <built-in method strip of str object at 0x789d3f30f2f0>
# Texto sin los espacios repetidos en el medio
# teXTo raro sIn formato
# reXTo  raro sIn formaro
# texto raro sin formato
# texto raro sin formato

# %%
#Como ingresar informacion

input("Ingrese su nombre" )
# Out:
# Ingrese su nombreDerekc
# 'Derekc'

# %%
#Guardar en un variable la información

nombre = input("Ingrese su nombre : ")

print("Nombre: " , nombre)

edad = input("Ingrese su edad: ")

print("Edad: ", edad)

print("Tipo de dato de la varible edad: ",type(edad))
#con el input todos los datos se guardan como tipo String
# Out:
# Ingrese su nombre : Derek
# Nombre:  Derek
# Ingrese su edad: 19
# Edad:  19
# Tipo de dato de la varible edad:  <class 'str'>

# %%
#Pasar de String a entero

edad = int(input("Ingrese su edad: "))
#con el int le decimos a la variable que va a guardar un dato entero es decir volvemos el String que resivimos del input en entero

print("Dato de edad  ", type(edad))

print("La edad es: " + str(edad))
#Esta es una forma para concatenar enteros con strings aqui se paso de entero a string

#Hacer Strings con formato , Metodo recomendado

print(f"La edad es: {edad}")
#En este formato se colocan llaves para indicar las variables y que todo se miprima como texto sin importar el tipo de dato que sea la variable
# Out:
# Ingrese su edad: 18
# Dato de edad   <class 'int'>
# La edad es: 18
# La edad es: 18

# %%
#Condicionales

nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: "))

if edad >= 18:
  print(f"{nombre} usted puede ingresar al establecimiento por que tiene {edad} años")
else:
  print(f"{nombre} usted no puede ingresar por que tiene {edad} años por lo tanto es menor de edad ")
# Out:
# Ingrese su nombre: Juan
# Ingrese su edad: 99
# Juan usted puede ingresar al establecimiento por que tiene 99 años

# %%
#Verificador si la persona aprobo o no

promedio = float(input("Ingrese su promedio: "))

if promedio >= 7:
  print(f"{nombre} Aprovo con un promedio de {promedio}")
elif promedio >= 5 and promedio<= 7 : # tiene que cumplirse las dos condiciones
  print(f"{nombre} tiene que recuperar su promedio es de {promedio}")
else:
  print(f"{nombre} reprobo con un promedio de {promedio}")
# Out:
# Ingrese su promedio: 6.1234
# Juan tiene que recuperar su promedio es de 6.1234

# %% [markdown]
# Aula 2: Uso de la IA

# %%
import os #importo esta libreria para trabajar con variables de entorno
from google.colab import userdata # agrego una libreria
userdata.get("Alura_gemini_api") # muestra mi api key

#Estamos guardando en la variable de entorno que llame alura curso el resultado que genera el codigo frente al igual el nombre de la variable sele
#coloca en elo corchetes []
os.environ["GEMINI_API_KEY"] = userdata.get("Alura_gemini_api") #Es obligatorio llamar asi la variable para que no de errores la variable de entorno

# %%
from google import genai # importamos esto por que poemos usar funcionalidades y herramientas para interaturas con la IA

client = genai.Client() #Se esta guardado en la variable client el motodo o funcion genai.Client() , creamos un objecto o instancia

# %%
client.models.generate_content(model = "gemini-2.5-flash",contents = "Que es la IA") # con model elegimos el modelo de gemini a usar y en contend hacemos nuestras preguntas
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""La **Inteligencia Artificial (IA)** es un campo de la informática que busca crear máquinas o programas capaces de "pensar", "razonar" y "aprender" de manera similar a los seres humanos, aunque sin poseer conciencia o emociones en el sentido biológico.
#
# En términos más sencillos, la IA es la ciencia y la ingeniería de hacer que los sistemas computacionales puedan realizar tareas que, tradicionalmente, requerirían inteligencia humana.
#
# Aquí te desgloso los puntos clave para entenderla:
#
# 1.  **Imitación de Capacidades Humanas:** No busca recrear un cerebro humano completo, sino imitar y automatizar habilidades cognitivas específicas como:
#     *   **Aprendizaje:** Las máquinas aprenden de datos, identifican patrones y mejoran su rendimiento con la experiencia (similar a cómo aprendemos de nuestras vivencias).
#     *   **Resolución de problemas:** Encuentran soluciones a desafíos complejos.
#     *   **Reconocimiento de patrones:** Identifican objetos en imágenes, voces en audio o anomalías en datos.
#     *   **Comprensión del lenguaje natural:** Entienden y procesan el lenguaje humano hablado o escrito.
#     *   **Toma de decisiones:** Seleccionan la mejor acción a seguir basándose en la información disponible.
#
# 2.  **Ramas Principales de la IA:**
#     *   **Machine Learning (Aprendizaje Automático):** Es la rama más popular. Permite a las máquinas aprender de los datos sin ser programadas explícitamente para cada tarea. Por ejemplo, un algoritmo aprende a distinguir entre fotos de perros y gatos viendo miles de ejemplos.
#     *   **Deep Learning (Aprendizaje Profundo):** Un subcampo del Machine Learning que utiliza redes neuronales artificiales con muchas capas (inspiradas en el cerebro humano) para reconocer patrones muy complejos en grandes volúmenes de datos. Es la base de muchas de las IA más avanzadas de hoy.
#     *   **Procesamiento del Lenguaje Natural (PLN):** Permite a las computadoras entender, interpretar y generar lenguaje humano. Es lo que usan asistentes virtuales como Siri o traductores automáticos.
#     *   **Visión por Computadora:** Permite a las máquinas "ver" e interpretar imágenes y videos, como el reconocimiento facial o los sistemas de conducción autónoma.
#     *   **Robótica (con IA):** Robótica que utiliza IA para percibir su entorno, tomar decisiones y ejecutar acciones de manera autónoma.
#
# 3.  **¿Para qué sirve la IA? (Ejemplos cotidianos):**
#     *   **Asistentes virtuales:** Siri, Alexa, Google Assistant.
#     *   **Recomendaciones:** Netflix (películas), Amazon (productos), Spotify (música).
#     *   **Coches autónomos:** Sistemas que permiten a los vehículos conducirse solos.
#     *   **Filtros de spam:** Que detectan y bloquean correos no deseados.
#     *   **Detección de fraude:** En bancos y transacciones online.
#     *   **Traducción automática:** Google Translate.
#     *   **Diagnóstico médico:** Ayudando a los médicos a analizar imágenes o datos de pacientes.
#     *   **Generación de contenido:** Como textos, imágenes o música (como yo, que soy un modelo de IA).
#
# 4.  **Importante Distinción:**
#     *   La IA actual es predominantemente "IA débil" o "IA estrecha" (Narrow AI): Está diseñada para tareas específicas y no posee conciencia, sentimientos ni una inteligencia general como la humana. Puede ser muy buena en su tarea, pero no puede transferir ese conocimiento a otras áreas.
#     *   La "IA fuerte" o "Inteligencia Artificial General (AGI)", que podría realizar cualquier tarea intelectual que un humano pueda hacer y poseer conciencia, es todavía un objetivo a largo plazo y un tema de investigación y debate.
#
# En resumen, la IA es la tecnología que permite a las máquinas realizar tareas inteligentes, aprender de la experiencia y adaptarse, lo que está transformando rápidamente casi todos los aspectos de nuestra vida y trabajo."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='8jUwapHUBOLVz7IPhcLiaA',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=875,
#     prompt_token_count=5,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=5
#       ),
#     ],
#     thoughts_token_count=1660,
#     total_token_count=2540
#   )
# )

# %%
#Guardando la respuesta de la ia en ua variable

respuesta = client.models.generate_content(model = "gemini-2.5-flash",contents = "Que es la IA") #aqui se hace la busqueda de la ia

# %%
print(respuesta.text) # Solo memuestra lo que esta dentro de text osea la respuesta de la ia
# Out:
# La **Inteligencia Artificial (IA)** es un campo de la informática que busca crear sistemas o máquinas que puedan realizar tareas que normalmente requieren inteligencia humana. En esencia, es la capacidad de las máquinas para imitar o simular la inteligencia humana.
#
# Piensa en ella como darle a una computadora la capacidad de "pensar", "razonar", aprender de la experiencia, entender el lenguaje, reconocer patrones, resolver problemas y tomar decisiones, de una manera similar a como lo hacemos los humanos.
#
# **¿Cómo funciona (de forma simplificada)?**
#
# La IA no es magia. Se basa en algoritmos (conjuntos de reglas e instrucciones) y, muy a menudo, en grandes cantidades de datos. Las máquinas son "entrenadas" con estos datos para:
#
# 1.  **Reconocer patrones:** Por ejemplo, en fotos para identificar objetos, o en texto para entender el significado.
# 2.  **Aprender de la experiencia:** Cuantos más datos procesa una IA, mejor se vuelve en sus tareas. Esto se conoce como **Aprendizaje Automático (Machine Learning)**, una de las ramas más importantes de la IA.
# 3.  **Hacer predicciones o tomar decisiones:** Basándose en los patrones que ha aprendido.
#
# **Características clave de la IA:**
#
# *   **Aprendizaje:** Las máquinas pueden aprender de datos y mejorar su rendimiento sin ser programadas explícitamente para cada situación.
# *   **Razonamiento:** Pueden aplicar reglas lógicas a la información para llegar a conclusiones.
# *   **Percepción:** Pueden interpretar información sensorial, como imágenes (visión por computadora) o sonidos (procesamiento del lenguaje natural).
# *   **Comprensión del lenguaje:** Pueden procesar y entender el lenguaje humano (hablado o escrito).
# *   **Resolución de problemas:** Pueden encontrar soluciones a problemas complejos.
#
# **Ejemplos cotidianos de IA:**
#
# La IA ya es una parte integral de nuestra vida diaria:
#
# *   **Asistentes virtuales:** Siri, Alexa, Google Assistant.
# *   **Sistemas de recomendación:** Lo que te sugiere Netflix, Amazon o Spotify.
# *   **Coches autónomos:** Aunque aún en desarrollo, utilizan IA para percibir el entorno y tomar decisiones.
# *   **Filtros de spam:** Que identifican correos no deseados.
# *   **Traducción automática:** Como Google Translate o DeepL.
# *   **Reconocimiento facial:** En tu teléfono o en sistemas de seguridad.
# *   **Diagnóstico médico:** Ayudando a los médicos a identificar enfermedades con mayor precisión.
# *   **Chatbots de atención al cliente:** Que responden tus preguntas en sitios web.
#
# **En resumen:**
#
# La Inteligencia Artificial es el campo que permite a las máquinas aprender, razonar y tomar decisiones, imitando la inteligencia humana. Es una herramienta poderosa que está transformando industrias y mejorando muchos aspectos de nuestra vida, desde cómo nos comunicamos hasta cómo trabajamos y nos divertimos.
